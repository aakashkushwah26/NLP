# %% [markdown]
# Tokenization of Paragraphs/Sentences

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Loop\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
x ="Natural Language Processing (NLP) in machine learning is a subfield of artificial intelligence (AI) focused on enabling machines to understand, interpret, and generate human language. It combines computational linguistics with machine learning techniques to process and analyze large volumes of textual or spoken data."

# %%
from nltk.tokenize import word_tokenize

# %%
 w = word_tokenize(x)

# %%
w
# Out:
# ['Natural',
#  'Language',
#  'Processing',
#  '(',
#  'NLP',
#  ')',
#  'in',
#  'machine',
#  'learning',
#  'is',
#  'a',
#  'subfield',
#  'of',
#  'artificial',
#  'intelligence',
#  '(',
#  'AI',
#  ')',
#  'focused',
#  'on',
#  'enabling',
#  'machines',
#  'to',
#  'understand',
#  ',',
#  'interpret',
#  ',',
#  'and',
#  'generate',
#  'human',
#  'language',
#  '.',
#  'It',
#  'combines',
#  'computational',
#  'linguistics',
#  'with',
#  'machine',
#  'learning',
#  'techniques',
#  'to',
#  'process',
#  'and',
#  'analyze',
#  'large',
#  'volumes',
#  'of',
#  'textual',
#  'or',
#  'spoken',
#  'data',
#  '.']

# %%
from nltk import pos_tag
p = pos_tag(w)

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Loop\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
p
# Out:
# [('Natural', 'JJ'),
#  ('Language', 'NNP'),
#  ('Processing', 'NNP'),
#  ('(', '('),
#  ('NLP', 'NNP'),
#  (')', ')'),
#  ('in', 'IN'),
#  ('machine', 'NN'),
#  ('learning', 'NN'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('subfield', 'NN'),
#  ('of', 'IN'),
#  ('artificial', 'JJ'),
#  ('intelligence', 'NN'),
#  ('(', '('),
#  ('AI', 'NNP'),
#  (')', ')'),
#  ('focused', 'VBD'),
#  ('on', 'IN'),
#  ('enabling', 'VBG'),
#  ('machines', 'NNS'),
#  ('to', 'TO'),
#  ('understand', 'VB'),
#  (',', ','),
#  ('interpret', 'VB'),
#  (',', ','),
#  ('and', 'CC'),
#  ('generate', 'VB'),
#  ('human', 'JJ'),
#  ('language', 'NN'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('combines', 'VBZ'),
#  ('computational', 'JJ'),
#  ('linguistics', 'NNS'),
#  ('with', 'IN'),
#  ('machine', 'NN'),
#  ('learning', 'VBG'),
#  ('techniques', 'NNS'),
#  ('to', 'TO'),
#  ('process', 'VB'),
#  ('and', 'CC'),
#  ('analyze', 'VB'),
#  ('large', 'JJ'),
#  ('volumes', 'NNS'),
#  ('of', 'IN'),
#  ('textual', 'JJ'),
# ...
