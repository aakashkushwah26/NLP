# %%
var ="Natural Language Processing (NLP) in machine learning is a subfield of artificial intelligence (AI) focused on enabling machines to understand, interpret, and generate human language. It combines computational linguistics with machine learning techniques to process and analyze large volumes of textual or spoken data."

# %%
var
# Out:
# 'Natural Language Processing (NLP) in machine learning is a subfield of artificial intelligence (AI) focused on enabling machines to understand, interpret, and generate human language. It combines computational linguistics with machine learning techniques to process and analyze large volumes of textual or spoken data.'

# %%
from nltk.tokenize import word_tokenize,sent_tokenize

# %%
sent=sent_tokenize(var)

# %%
sent
# Out:
# ['Natural Language Processing (NLP) in machine learning is a subfield of artificial intelligence (AI) focused on enabling machines to understand, interpret, and generate human language.',
#  'It combines computational linguistics with machine learning techniques to process and analyze large volumes of textual or spoken data.']

# %%
for i in sent:
    print(i)
    print()
# Out:
# Natural Language Processing (NLP) in machine learning is a subfield of artificial intelligence (AI) focused on enabling machines to understand, interpret, and generate human language.
#
# It combines computational linguistics with machine learning techniques to process and analyze large volumes of textual or spoken data.

# %%
word = word_tokenize(var)

# %%
word
# Out:
# ['Natural',
#  'Language',
#  'Processing',
#  '(',
#  'NLP',
#  ')',
#  'in',
#  'machine',
#  'learning',
#  'is',
#  'a',
#  'subfield',
#  'of',
#  'artificial',
#  'intelligence',
#  '(',
#  'AI',
#  ')',
#  'focused',
#  'on',
#  'enabling',
#  'machines',
#  'to',
#  'understand',
#  ',',
#  'interpret',
#  ',',
#  'and',
#  'generate',
#  'human',
#  'language',
#  '.',
#  'It',
#  'combines',
#  'computational',
#  'linguistics',
#  'with',
#  'machine',
#  'learning',
#  'techniques',
#  'to',
#  'process',
#  'and',
#  'analyze',
#  'large',
#  'volumes',
#  'of',
#  'textual',
#  'or',
#  'spoken',
#  'data',
#  '.']
